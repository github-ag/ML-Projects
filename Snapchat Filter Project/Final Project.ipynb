# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
import os

# %%
folders = os.listdir()
print(folders)
# Out:
# ['.ipynb_checkpoints', 'Final Project.ipynb', 'frontalEyes35x16.xml', 'glasses.png', 'Images', 'Jamie_After.jpg', 'Jamie_Before.jpg', 'mustache.png', 'Nose18x15.xml', 'photo.jpg', 'photo1.jpg', 'sunglasses.jpg', 'testing project.ipynb', 'testing the classifier.py', 'third-party']

# %%
imags = os.listdir("Images")
print(imags)
# Out:
# ['IMG_20180612_001824_731.jpg', 'IMG_20190412_122009.jpg', 'photo.jpg']

# %%
for img_name in imags:
    path = "Images/"+img_name
    img = cv2.imread(path)
    img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
    plt.imshow(img)
    plt.show()

# %%
eyes_cascade = cv2.CascadeClassifier('frontalEyes35x16.xml')

# %%
for img_name in imags:
    path = "Images/"+img_name
    img = cv2.imread(path)
    img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
    eyes = eyes_cascade.detectMultiScale(img,1.0005,30,maxSize=(1000,1000),minSize=(100,100))
    print(eyes)
    print('\n')
    
    for eye in eyes:
        x,y,w,h = eye
        
        glasses = cv2.imread("sunglasses.jpg")

        glasses = cv2.cvtColor(glasses,cv2.COLOR_RGB2BGR)
        glasses = cv2.resize(glasses,(w*3,int(h/2)))
        for c in range(3):
            for a in range(glasses.shape[0]):
                for b in range(glasses.shape[1]):
                    if glasses[a][b][0]!=255 or glasses[a][b][1]!=255 or glasses[a][b][2]!=255: # To remove the white part in glasses
                        img[y+a][x+b][c] = glasses[a][b][c]
    
    plt.imshow(img)
    plt.show()
# Out:
# [[198 509 126 275]
#  [588 168 112 246]]
# [[1260 2696  118  258]
#  [ 908 2612  140  306]
#  [ 445 4221  181  397]
#  [1642 1532  316  691]
#  [1394 3186  105  230]
#  [ 747 2953  408  893]]
# [[410 451 152 334]]
